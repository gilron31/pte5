# %%
# %load_ext autoreload
# %autoreload 2

from utils import *
import numpy as np
import torch
from loguru import logger
import itertools


from enumeration_v1 import Enumerator

# %%
BOUND = 200

enum = Enumerator(BOUND, remove_2=False)
len(enum.factor_base)
# Out:
# ...
# 100%|██████████| 22/22 [00:00<00:00, 203248.21it/s]
# 22

# %%
enum.canonize_to_first_eighth(
    enum.get_all_points_from_factorization([2, 5, 13, 17, 61])
)
# Out:
# [(11, 367),
#  (77, 359),
#  (101, 353),
#  (131, 343),
#  (229, 287),
#  (163, 329),
#  (67, 361),
#  (241, 277)]

# %%
enum.meet_points_from_factorization([5, 13, 17, 61], 4)
# Out:
# 100%|██████████| 35/35 [00:00<00:00, 82057.37it/s]
# [((5, 13, 17, 61),
#   [(126, 227),
#    (29, 258),
#    (178, 189),
#    (141, 218),
#    (106, 237),
#    (83, 246),
#    (18, 259),
#    (147, 214)],
#   {1762899048: [(3, 0), (4, 2)]})]

# %%
enum.meet_points_from_factorization([5, 13, 17, 61])
# Out:
# ([5, 13, 17, 61],
#  [(126, 227),
#   (29, 258),
#   (178, 189),
#   (141, 218),
#   (106, 237),
#   (83, 246),
#   (18, 259),
#   (147, 214)],
#  {1762899048: [(3, 0), (4, 2)]})

# %%
enum.meet_points_from_factorization([2, 5, 13, 17, 61], 5)
# Out:
# 100%|██████████| 126/126 [00:00<00:00, 65252.78it/s]
# [((2, 5, 13, 17, 61),
#   [(11, 367),
#    (77, 359),
#    (101, 353),
#    (131, 343),
#    (229, 287),
#    (163, 329),
#    (67, 361),
#    (241, 277)],
#   {2035271858: [(2, 1), (3, 0)]})]

# %%
enum.meet_points_from_factor_base(4)
# Out:
# ...
# 100%|██████████| 12650/12650 [00:00<00:00, 94817.95it/s]
# [((5, 13, 17, 61),
#   [(126, 227),
#    (29, 258),
#    (178, 189),
#    (141, 218),
#    (106, 237),
#    (83, 246),
#    (18, 259),
#    (147, 214)],
#   {1762899048: [(3, 0), (4, 2)]}),
#  ((5, 29, 41, 101),
#   [(366, 683),
#    (117, 766),
#    (206, 747),
#    (507, 586),
#    (37, 774),
#    (494, 597),
#    (54, 773),
#    (474, 613)],
#   {86168670408: [(2, 0), (7, 6)]})]

# %%
res = enum.meet_points_from_factor_base(4, with_multiplicity=False)
res = enum.enrich_results(res)
# res
# Out:
# 100%|██████████| 7315/7315 [00:00<00:00, 88936.30it/s]
# 2025-12-14 22:53:49.384 | INFO     | utils:analyze_E4_sol:17 - ##########################################
# 2025-12-14 22:53:49.384 | INFO     | utils:analyze_E4_sol:18 - (((77, 359), (101, 353)), ((131, 343), (11, 367)))
# 2025-12-14 22:53:49.384 | INFO     | utils:analyze_E4_sol:19 - radius=134810: {2: 1, 5: 1, 13: 1, 17: 1, 61: 1}
# 2025-12-14 22:53:49.385 | INFO     | utils:analyze_E4_sol:20 - P=67405: {5: 1, 13: 1, 17: 1, 61: 1}
# 2025-12-14 22:53:49.385 | INFO     | utils:analyze_E4_sol:21 - Q_m=2035271858: {2: 1, 17: 1, 313: 1, 191249: 1}
# 2025-12-14 22:53:49.385 | INFO     | utils:analyze_E4_sol:22 - Q_a=32276928484: {2: 2, 17: 1, 474660713: 1}
# 2025-12-14 22:53:49.385 | INFO     | utils:analyze_E4_sol:23 - L_2=3525798096: {2: 4, 3: 2, 17: 1, 1049: 1, 1373: 1}
# 2025-12-14 22:53:49.385 | INFO     | utils:analyze_E4_sol:17 - ##########################################
# ...

# %%
# enum.meet_points_from_factor_base(5, with_multiplicity=False)
