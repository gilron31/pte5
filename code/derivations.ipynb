# %%
import sympy as sp

# %%
x, P, Q, R, S, T = sp.var("x, P, Q, R, S, T")
E_x_P = x**2 - P
E_x_P_Q = E_x_P**2 - Q
E_x_P_Q_R = E_x_P_Q**2 - R
E_x_P_Q_R_S = E_x_P_Q_R**2 - S
E_x_P_Q_R_S_T = E_x_P_Q_R_S**2 - T

E1 = E_x_P
E2 = E_x_P_Q
E3 = E_x_P_Q_R
E4 = E_x_P_Q_R_S
E5 = E_x_P_Q_R_S_T

# %%
E3.as_poly(x)
# Out:
# Poly(x**8 - 4*P*x**6 + (6*P**2 - 2*Q)*x**4 + (-4*P**3 + 4*P*Q)*x**2 + P**4 - 2*P**2*Q + Q**2 - R, x, domain='ZZ[P,Q,R]')
