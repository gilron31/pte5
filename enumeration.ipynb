# %%
import sympy as sp
import numpy as np
import math
import collections
import tqdm
import itertools
import random
from loguru import logger

import utils
import enumeration

# %%
enum = enumeration.Enumerator(10**8, 10**5)
# Out:
# ...
# 100%|██████████| 4784/4784 [00:00<00:00, 88658.13it/s]

# %%
enum.enumerate_radius_factorized(sp.factorint(2 * 5 * 13 * 17))
# Out:
# [(43, 19), (37, 29), (47, 1), (41, 23)]
# [[43 19]
#  [37 29]
#  [47  1]
#  [41 23]]

# %%
len(enum.primes)
# Out:
# 4784

# %%
2**64
# Out:
# 18446744073709551616
